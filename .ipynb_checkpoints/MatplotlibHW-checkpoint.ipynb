# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data = "//Users//deankleto//Desktop//matplotlib-challenge//data//mouse_drug_data.csv"
clinical_trial_data = "//Users/deankleto//Desktop//matplotlib-challenge//data//clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_drug_df = pd.read_csv(mouse_drug_data)
clinical_trial_df = pd.read_csv(clinical_trial_data)

# Combine the data into a single dataset
combine_drugtrial_data = pd.merge(mouse_drug_df, clinical_trial_df, on="Mouse ID")
combine_drugtrial_data.head()
# Display the data table for preview
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
grouped_drugtrial_df_se = combine_drugtrial_data.groupby(['Drug','Timepoint']).sem()["Tumor Volume (mm3)"]
grouped_drugtrial_df_mean = combine_drugtrial_data.groupby(['Drug','Timepoint']).mean()["Tumor Volume (mm3)"]
# Preview DataFrame
grouped_drugtrial_df_mean.head(5)
grouped_drugtrial_df_se
# Out:
# Drug       Timepoint
# Capomulin  0            0.000000
#            5            0.448593
#            10           0.702684
#            15           0.838617
#            20           0.909731
#            25           0.881642
#            30           0.934460
#            35           1.052241
#            40           1.223608
#            45           1.223977
# Ceftamin   0            0.000000
#            5            0.164505
#            10           0.236144
#            15           0.332053
#            20           0.359482
#            25           0.439356
#            30           0.490620
#            35           0.692248
#            40           0.708505
#            45           0.902358
# Infubinol  0            0.000000
#            5            0.235102
#            10           0.282346
#            15           0.357705
#            20           0.476210
#            25           0.550315
#            30           0.631061
# ...

# %%
drop_df = grouped_drugtrial_df_se[["Drug", "Timepoint", "Tumor Volume (mm3)"]]
drop_df.head()
# Out:
# Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
grouped_drugtrial_df_se.describe()
# Out:
# count    100.000000
# mean       0.691003
# std        0.428934
# min        0.000000
# 25%        0.359038
# 50%        0.705595
# 75%        0.999683
# max        1.888586
# Name: Tumor Volume (mm3), dtype: float64

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint
grouped_drugtrial_df_mean2=pd.DataFrame(grouped_drugtrial_df_mean)
grouped_drugtrial_df_se2=pd.DataFrame(grouped_drugtrial_df_se)

mean = grouped_drugtrial_df_mean2[['Tumor Volume (mm3)']]
standard_error = [sem(s) for s in grouped_drugtrial_df_se]
# Convert to DataFrame

# Preview DataFrame
mean
#standard_error
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325
#           25                  39.939528
#           30                  38.769339
#           35                  37.816839
#           40                  36.958001
#           45                  36.236114
# Ceftamin  0                   45.000000
#           5                   46.503051
#           10                  48.285125
#           15                  50.094055
#           20                  52.157049
#           25                  54.287674
#           30                  56.769517
#           35                  58.827548
#           40                  61.467895
#           45                  64.132421
# Infubinol 0                   45.000000
#           5                   47.062001
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
drugs = combine_drugtrial_data[["Drug"]]
drugs
# Out:
#           Drug
# 0     Stelasyn
# 1     Stelasyn
# 2     Stelasyn
# 3     Stelasyn
# 4     Stelasyn
# 5     Stelasyn
# 6     Stelasyn
# 7     Stelasyn
# 8     Stelasyn
# 9     Stelasyn
# 10    Stelasyn
# 11    Stelasyn
# 12    Stelasyn
# 13    Stelasyn
# 14    Stelasyn
# 15    Stelasyn
# 16    Stelasyn
# 17    Stelasyn
# 18    Stelasyn
# 19    Stelasyn
# 20    Stelasyn
# 21    Stelasyn
# 22    Stelasyn
# 23    Stelasyn
# 24    Stelasyn
# 25    Stelasyn
# 26    Stelasyn
# 27    Stelasyn
# 28    Stelasyn
# 29    Stelasyn
# ...        ...
# 1876   Placebo
# 1877   Placebo
# 1878   Placebo
# 1879   Placebo
# 1880   Placebo
# 1881   Placebo
# 1882   Placebo
# 1883   Placebo
# 1884   Placebo
# 1885   Placebo
# 1886   Placebo
# 1887   Placebo
# 1888   Placebo
# 1889   Placebo
# 1890   Placebo
# 1891   Placebo
# 1892   Placebo
# 1893   Placebo
# 1894   Placebo
# 1895   Placebo
# 1896   Placebo
# 1897   Placebo
# 1898   Placebo
# 1899   Placebo
# 1900   Placebo
# 1901   Placebo
# ...

# %%
# Generate the Plot (with Error Bars)

fig, ax = plt.subplots()

ax.errorbar(x_axis, mean, standard_error, fmt="o")

ax.set_xlim(-1, len(drugs) + 1)

ax.set_xlabel("Timepoint")
ax.set_ylabel("Tumor Volume (mm3)")
# Save the Figure

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-f091cc96db7b> in <module>
#       3 fig, ax = plt.subplots()
#       4
# ----> 5 ax.errorbar(x_axis, mean, standard_error, fmt="o")
#       6
#       7 ax.set_xlim(-1, len(drugs) + 1)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3422
#    3423         if yerr is not None:
# ...

# %%
# Show the Figure
plt.show()

# %% [markdown]
# ![Tumor Response to Treatment](../Images/treatment.png)

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint <<<<<<<counts on DF>>>>>>>>>>>

# Convert to DataFrame
grouped_drugtrial_df_se1 = combine_drugtrial_data.groupby(['Drug','Timepoint']).sem()["Metastatic Sites"]
grouped_drugtrial_df_mean1 = combine_drugtrial_data.groupby(['Drug','Timepoint']).mean()["Metastatic Sites"]
# Preview DataFrame
grouped_drugtrial_df_mean1.head()
grouped_drugtrial_df_se1
# Preview DataFrame
ms_df = pd.DataFrame(grouped_drugtrial_df_mean1)
ms_df
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174
#           25                 0.818182
#           30                 1.090909
#           35                 1.181818
#           40                 1.380952
#           45                 1.476190
# Ceftamin  0                  0.000000
#           5                  0.380952
#           10                 0.600000
#           15                 0.789474
#           20                 1.111111
#           25                 1.500000
#           30                 1.937500
#           35                 2.071429
#           40                 2.357143
#           45                 2.692308
# Infubinol 0                  0.000000
#           5                  0.280000
#           10                 0.666667
# ...

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 
grouped_drugtrial_df_mean3=pd.DataFrame(grouped_drugtrial_df_mean1)
grouped_drugtrial_df_se3=pd.DataFrame(grouped_drugtrial_df_se1)
# Convert to DataFrame
mean = grouped_drugtrial_df_mean3[['Metastatic Sites']]
standard_error = [sem(s) for s in grouped_drugtrial_df_se]
                 
# Preview DataFrame
ms_se_df = pd.DataFrame(mean)
ms_se_df
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174
#           25                 0.818182
#           30                 1.090909
#           35                 1.181818
#           40                 1.380952
#           45                 1.476190
# Ceftamin  0                  0.000000
#           5                  0.380952
#           10                 0.600000
#           15                 0.789474
#           20                 1.111111
#           25                 1.500000
#           30                 1.937500
#           35                 2.071429
#           40                 2.357143
#           45                 2.692308
# Infubinol 0                  0.000000
#           5                  0.280000
#           10                 0.666667
# ...

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
# Generate the Plot (with Error Bars)

# Save the Figure

# Show the Figure

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/spread.png)

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame

# Preview DataFrame

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure
plt.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/survival.png)

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

# Display the data to confirm

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs


# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()

# %% [markdown]
# ![Metastatic Spread During Treatment](../Images/change.png)
